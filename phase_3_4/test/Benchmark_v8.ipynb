# %%
# ! nvcc -arch=sm_75 -O3 --use_fast_math \
#     gpu_conv2d_fp16_backward_v3.cu \
#     test_backward_v3.cu \
#     -o test_v3

! ./test_v3
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# [ReLU] Stage3: err=0.000162361 PASS
# [BackIn] Stage3: err=0.000326436 PASS
# [BackW] Stage3: w_err=0.000259772 b_err=0.000252751 PASS
# [Fused] Stage3: err=0.0003269 PASS
# [ReLU] Stage4: err=0.000162543 PASS
# [BackIn] Stage4: err=0.000328202 PASS
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v4.cu \
    test_backward_v4.cu \
    -o test_v4

# !./test_v4
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# [ReLU] Stage3: err=0.000162361 PASS
# [BackIn] Stage3: err=0.000326436 PASS
# [BackW] Stage3: w_err=0.000259772 b_err=0.000252751 PASS
# [Fused] Stage3: err=0.0003269 PASS
# [ReLU] Stage4: err=0.000162543 PASS
# [BackIn] Stage4: err=0.000328202 PASS
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v4_new.cu \
    test_backward_v4_new.cu \
    -o test_v4_new

# !./test_v4_new
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# [ReLU] Stage3: err=0.000162361 PASS
# [BackIn] Stage3: err=0.000326436 PASS
# [BackW] Stage3: w_err=0.000259772 b_err=0.000252751 PASS
# [Fused] Stage3: err=0.0003269 PASS
# [ReLU] Stage4: err=0.000162543 PASS
# [BackIn] Stage4: err=0.000328202 PASS
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v5.cu \
    test_backward_v5.cu \
    -o test_v5

! ./test_v5
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# [ReLU] Stage3: err=0.000162361 PASS
# [BackIn] Stage3: err=0.000326436 PASS
# [BackW] Stage3: w_err=0.000259772 b_err=0.000252751 PASS
# [Fused] Stage3: err=0.0003269 PASS
# [ReLU] Stage4: err=0.000162543 PASS
# [BackIn] Stage4: err=0.000328202 PASS
# ...

# %%
# !nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v6.cu \
    test_backward_v6.cu \
    -o test_v6

# !./test_v6
# Out:
# gpu_conv2d_fp16_backward_v6.cu(165): warning #177-D: variable "s_base" was declared but never referenced
#       int s_base = 0;
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v7.cu \
    test_backward_v7.cu \
    -o test_v7

! ./test_v7
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: err=0.000160692 PASS
# [BackIn] Tiny: err=0.000326939 PASS
# [BackW] Tiny: w_err=0.000266644 b_err=0.000189036 PASS
# [Fused] Tiny: err=0.000330835 PASS
# [ReLU] Small: err=0.000162361 PASS
# [BackIn] Small: err=0.000327112 PASS
# [BackW] Small: w_err=0.000260376 b_err=0.000252751 PASS
# [Fused] Small: err=0.000327871 PASS
# [ReLU] Stage1: err=0.000161849 PASS
# [BackIn] Stage1: err=0.000325642 PASS
# [BackW] Stage1: w_err=0.000264704 b_err=0.000185562 PASS
# [Fused] Stage1: err=0.00032816 PASS
# [ReLU] Stage2: err=0.000162718 PASS
# [BackIn] Stage2: err=0.000327618 PASS
# [BackW] Stage2: w_err=0.000260999 b_err=0.000188572 PASS
# [Fused] Stage2: err=0.000327554 PASS
# [ReLU] Stage3: err=0.000162361 PASS
# [BackIn] Stage3: err=0.000326436 PASS
# [BackW] Stage3: w_err=0.000259772 b_err=0.000252751 PASS
# [Fused] Stage3: err=0.0003269 PASS
# [ReLU] Stage4: err=0.000162543 PASS
# [BackIn] Stage4: err=0.000328202 PASS
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    autoencoder_ops.cu \
    test_autoencoder_ops.cu \
    -o test_autoencoder

! ./test_autoencoder
# Out:
# === AUTOENCODER OPS TESTS ===
#
# Testing MaxPool2D: N=2, H=32, W=32, C=256
#   Forward: max_err=0.001875, idx_errors=0 - PASS
#   Backward: max_err=0.001875 - PASS
# Testing MaxPool2D: N=64, H=32, W=32, C=256
#   Forward: max_err=0.001875, idx_errors=0 - PASS
#   Backward: max_err=0.001875 - PASS
# Testing MaxPool2D: N=64, H=16, W=16, C=128
#   Forward: max_err=0.001875, idx_errors=0 - PASS
#   Backward: max_err=0.001875 - PASS
# Testing Upsample2D: N=2, H=8, W=8, C=128
#   Forward: max_err=0.001875 - PASS
#   Backward: max_err=0.008751 - PASS
# Testing Upsample2D: N=64, H=8, W=8, C=128
#   Forward: max_err=0.001875 - PASS
#   Backward: max_err=0.012501 - PASS
# Testing Upsample2D: N=64, H=16, W=16, C=256
#   Forward: max_err=0.001875 - PASS
#   Backward: max_err=0.013750 - PASS
# Testing MSELoss: size=1024
#   Loss: ref=16.144615, gpu=16.144407, rel_err=0.000013
#   Grad: max_err=0.000013 - PASS
# Testing MSELoss: size=196608
# ...

# %%
! nvcc -arch=sm_75 -O3 --use_fast_math \
    gpu_conv2d_fp16_backward_v8.cu \
    test_backward_v8.cu \
    -o test_v8

! ./test_v8
# Out:
# Device: Tesla T4 (SM75)
#
# === CORRECTNESS TESTS ===
# [ReLU] Tiny: 0.000160692 PASS
# [BackIn] Tiny: 0.000326939 PASS
# [BackW] Tiny: w=0.000297036 b=0.000195479 PASS
# [BackW+SGD] Tiny: w=3.32543e-06 b=4.15051e-05 fp16=3.05176e-05 PASS
# [Fused] Tiny: 0.000330835 PASS
# [ReLU] Small: 0.000162361 PASS
# [BackIn] Small: 0.000327112 PASS
# [BackW] Small: w=0.000293873 b=0.000265645 PASS
# [BackW+SGD] Small: w=9.68876e-06 b=0.000126368 fp16=3.05176e-05 PASS
# [Fused] Small: 0.000327871 PASS
# [ReLU] Stage1: 0.000161849 PASS
# [BackIn] Stage1: 0.000325642 PASS
# [BackW] Stage1: w=0.000295812 b=0.000200044 PASS
# [BackW+SGD] Stage1: w=3.89353e-05 b=0.000183411 fp16=3.05101e-05 PASS
# [Fused] Stage1: 0.00032816 PASS
# [ReLU] Stage2: 0.000162718 PASS
# [BackIn] Stage2: 0.000327618 PASS
# [BackW] Stage2: w=0.000294877 b=0.000219353 PASS
# [BackW+SGD] Stage2: w=1.87258e-05 b=0.000156474 fp16=3.05176e-05 PASS
# [Fused] Stage2: 0.000327554 PASS
# [ReLU] Stage3: 0.000162361 PASS
# ...
